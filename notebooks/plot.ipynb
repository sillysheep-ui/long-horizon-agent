# %% [markdown]
# # 可视化绘图与分析

# %%
log_path = "../saved/output/grpo_parser_aligned_run/v8-20260514-140934/logging.jsonl"

import pandas as pd
df = pd.read_json(log_path, lines=True)
df
# Out:
#              loss  grad_norm  learning_rate  completions/mean_length  \
# 0   -7.100000e-07   1.615341   1.000000e-06              1286.333374
# 1    1.900000e-05   0.506693   1.000000e-06              6237.666992
# 2    2.317000e-05   1.083081   1.000000e-06              2244.500000
# 3    1.719000e-05   1.898017   1.000000e-06              1146.166748
# 4    2.277000e-05   0.639829   1.000000e-06              3183.000000
# ..            ...        ...            ...                      ...
# 162  2.110700e-04   1.507655   8.000000e-08              2025.333374
# 163  3.297500e-04   1.993843   8.000000e-08              1266.500000
# 164  2.352500e-04   1.572343   7.000000e-08              1069.833374
# 165  2.023000e-04   0.775945   7.000000e-08              1589.500000
# 166  2.105800e-04   0.853004   7.000000e-08              3126.333496
#
#      completions/min_length  completions/max_length  \
# 0                      1090                    1437
# ...

# %%
df.keys()
# Out:
# Index(['loss', 'grad_norm', 'learning_rate', 'completions/mean_length',
#        'completions/min_length', 'completions/max_length',
#        'completions/clipped_ratio', 'num_turns', 'reward', 'reward_std',
#        'frac_reward_zero_std', 'rewards/ParserAlignedCurriculumReward/mean',
#        'rewards/ParserAlignedCurriculumReward/std', 'kl',
#        'clip_ratio/low_mean', 'clip_ratio/low_min', 'clip_ratio/high_mean',
#        'clip_ratio/high_max', 'clip_ratio/region_mean', 'epoch',
#        'global_step/max_steps', 'elapsed_time', 'remaining_time',
#        'memory(GiB)', 'train_speed(s/it)'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(df["loss"])
plt.title("loss", fontsize=14)
# Out:
# Text(0.5, 1.0, 'loss')

# %%
plt.plot(df["learning_rate"])
plt.title("learning_rate", fontsize=14)
# Out:
# Text(0.5, 1.0, 'learning_rate')

# %%
plt.plot(df["reward"])
plt.title("reward", fontsize=14)
# Out:
# Text(0.5, 1.0, 'reward')

# %%
plt.plot(df["reward_std"])
plt.title("reward_std", fontsize=14)
# Out:
# Text(0.5, 1.0, 'reward_std')

# %%
plt.plot(df["num_turns"])
plt.title("num_turns", fontsize=14)
# Out:
# Text(0.5, 1.0, 'num_turns')

# %%
plt.plot(df["train_speed(s/it)"])
plt.title("train_speed(s/it)", fontsize=14)
# Out:
# Text(0.5, 1.0, 'train_speed(s/it)')
